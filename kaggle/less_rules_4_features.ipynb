# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

df=pd.DataFrame()
for no in range(10,38):
    temp=pd.read_csv("Processed Data/fileID"+str(no)+"_ProcessedTripData.csv",header= None)
    #print(temp)  
    df=pd.concat([df,temp])

df.columns=['Time','Vehicle Speed','SHIFT','Engine Load','Total Acceleration','Engine RPM','Pitch','Lateral Acceleration','Passenger Count','Car Load','AC Status','Window Opening','Radio Volume','Rain Intensity','Visibility','Driver Wellbeing','Driver Rush']

# Multiply the 'Vehicle Speed' by 3.6 to get km/h
df['Vehicle Speed'] = df['Vehicle Speed'] * 3.6

newdf = df[df.SHIFT != 0]
newdf = newdf.reset_index(drop=True)

# Column SHIFT moved to the last position
column_to_move = 'SHIFT'
columns = [col for col in newdf.columns if col != column_to_move]
newdf = newdf[columns + [column_to_move]]

df = newdf

df.dropna(inplace=True)

# Set the display format to show real numbers, not scientific notation
pd.set_option('display.float_format', lambda x: '%.3f' % x)

df.describe()
# Out:
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID11_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID32_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID13_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID9_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID26_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID19_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID2_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID33_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID36_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID21_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID14_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID20_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID29_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID31_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID27_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID34_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID23_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID25_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID15_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID17_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID28_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID5_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID35_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID38_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID22_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID4_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID6_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID16_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID1_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/readme.rtf
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID10_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID37_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID30_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID8_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID18_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID3_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID12_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID7_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/Processed Data/fileID24_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/TripData/__MACOSX/Processed Data/._readme.rtf
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID11_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID32_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID13_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID9_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID26_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID19_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID2_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID33_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID36_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID21_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID14_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID20_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID29_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID31_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID27_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID34_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID23_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID25_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID15_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID17_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID28_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID5_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID35_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID38_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID22_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID4_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID6_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID16_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID1_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/readme.rtf
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID10_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID37_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID30_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID8_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID18_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID3_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID12_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID7_ProcessedTripData.csv
# /home/vortex/isep/project/datasets/gear-box-prediction/Processed Data/fileID24_ProcessedTripData.csv
#              Time  Vehicle Speed  Engine Load  Total Acceleration  Engine RPM  \
# count 3228015.000    3228015.000  3228015.000         3228015.000 3228015.000
# mean     1342.519         46.641       10.357               0.272    2039.619
# std       901.246         24.403        8.100               0.694     553.765
# min         7.677          4.773        2.000              -5.101     800.020
# 25%       585.950         28.186        4.122              -0.148    1674.200
# 50%      1238.500         42.264        8.054               0.223    1987.300
# 75%      1886.900         64.890       13.584               0.626    2292.400
# max      4287.900        115.150       69.655               4.523    5680.800
#
#             Pitch  Lateral Acceleration  Passenger Count    Car Load  \
# count 3228015.000           3228015.000      3228015.000 3228015.000
# mean        1.244                -0.021            0.658       4.639
# std         1.896                 0.521            0.859       2.165
# min       -10.549                -5.963            0.000       3.000
# 25%         0.604                -0.111            0.000       3.000
# 50%         1.307                -0.006            0.000       3.000
# 75%         1.970                 0.085            1.000       7.000
# max        12.277                 5.777            4.000       8.000
#
#         AC Status  Window Opening  Radio Volume  Rain Intensity  Visibility  \
# count 3228015.000     3228015.000   3228015.000     3228015.000 3228015.000
# mean        0.086           0.593         3.469           0.152       9.676
# std         0.372           1.309         2.105           0.532       0.678
# min         0.000           0.000         0.000           0.000       7.000
# 25%         0.000           0.000         2.000           0.000      10.000
# 50%         0.000           0.000         4.000           0.000      10.000
# 75%         0.000           0.000         5.000           0.000      10.000
# max         4.000           6.000         8.000           3.000      10.000
#
#        Driver Wellbeing  Driver Rush       SHIFT
# count       3228015.000  3228015.000 3228015.000
# mean              6.510        3.016       3.412
# std               1.058        1.083       1.256
# min               4.000        0.000       1.000
# 25%               6.000        3.000       2.000
# 50%               7.000        3.000       3.000
# 75%               7.000        3.000       5.000
# max               8.000        5.000       5.000

# %%
df.head()
# Out:
#     Time  Vehicle Speed  Engine Load  Total Acceleration  Engine RPM  Pitch  \
# 0 60.569          9.987        7.843              -0.173    1306.500 -1.625
# 1 60.579          9.965        7.826              -0.195    1308.800 -1.642
# 2 60.589          9.940        7.809              -0.214    1311.100 -1.659
# 3 60.599          9.910        7.791              -0.231    1313.600 -1.676
# 4 60.608          9.893        7.774              -0.245    1316.100 -1.693
#
#    Lateral Acceleration  Passenger Count  Car Load  AC Status  Window Opening  \
# 0                 1.599                0         3          0               2
# 1                 1.599                0         3          0               2
# 2                 1.595                0         3          0               2
# 3                 1.568                0         3          0               2
# 4                 1.565                0         3          0               2
#
#    Radio Volume  Rain Intensity  Visibility  Driver Wellbeing  Driver Rush  \
# 0             6               0           9                 5            3
# 1             6               0           9                 5            3
# 2             6               0           9                 5            3
# 3             6               0           9                 5            3
# 4             6               0           9                 5            3
#
#    SHIFT
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
# Feature Importance
# No GridSearchCV take into consideration
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

X = df.drop(columns=['SHIFT'])
y = df['SHIFT']

# Train a Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X, y)

# Get feature importance
feature_importance = clf.feature_importances_
feature_names = X.columns

feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})

print(feature_importance_df.sort_values(by='Importance', ascending=False))
# Out:
#                  Feature  Importance
# 1          Vehicle Speed       0.690
# 4             Engine RPM       0.268
# 8               Car Load       0.024
# 3     Total Acceleration       0.015
# 5                  Pitch       0.002
# 6   Lateral Acceleration       0.001
# 0                   Time       0.001
# 11          Radio Volume       0.000
# 2            Engine Load       0.000
# 10        Window Opening       0.000
# 14      Driver Wellbeing       0.000
# 13            Visibility       0.000
# 12        Rain Intensity       0.000
# 7        Passenger Count       0.000
# 9              AC Status       0.000
# 15           Driver Rush       0.000

# %%
# Correlation Matrix
# ALL FEATURES no seaborn graph
# No GridSearchCV take into consideration

correlation_matrix = df.corr()

print(correlation_matrix)
# Out:
#                        Time  Vehicle Speed  Engine Load  Total Acceleration  \
# Time                  1.000          0.133       -0.039               0.010
# Vehicle Speed         0.133          1.000        0.368              -0.067
# Engine Load          -0.039          0.368        1.000               0.695
# Total Acceleration    0.010         -0.067        0.695               1.000
# Engine RPM            0.027          0.675        0.672               0.246
# Pitch                 0.084          0.043        0.383               0.515
# Lateral Acceleration -0.004          0.001       -0.025              -0.028
# Passenger Count      -0.024          0.190        0.066               0.039
# Car Load              0.338          0.669        0.151              -0.030
# AC Status            -0.103         -0.140        0.049               0.023
# Window Opening       -0.297         -0.178       -0.047               0.006
# Radio Volume         -0.258         -0.323        0.059               0.065
# Rain Intensity       -0.023         -0.211       -0.001               0.052
# Visibility           -0.004          0.296        0.068              -0.016
# Driver Wellbeing      0.114          0.271        0.061              -0.021
# Driver Rush           0.187         -0.002        0.001              -0.003
# SHIFT                 0.153          0.859        0.057              -0.225
#
#                       Engine RPM  Pitch  Lateral Acceleration  \
# Time                       0.027  0.084                -0.004
# Vehicle Speed              0.675  0.043                 0.001
# Engine Load                0.672  0.383                -0.025
# Total Acceleration         0.246  0.515                -0.028
# Engine RPM                 1.000  0.125                 0.001
# Pitch                      0.125  1.000                -0.032
# Lateral Acceleration       0.001 -0.032                 1.000
# Passenger Count            0.066  0.102                -0.017
# Car Load                   0.307  0.033                 0.002
# AC Status                 -0.012  0.008                -0.001
# Window Opening            -0.094 -0.011                -0.006
# Radio Volume              -0.040  0.067                 0.003
# Rain Intensity            -0.075  0.061                -0.001
# Visibility                 0.152  0.018                -0.007
# Driver Wellbeing           0.119 -0.011                -0.005
# Driver Rush                0.033 -0.018                 0.021
# SHIFT                      0.262 -0.015                 0.004
#
#                       Passenger Count  Car Load  AC Status  Window Opening  \
# Time                           -0.024     0.338     -0.103          -0.297
# Vehicle Speed                   0.190     0.669     -0.140          -0.178
# Engine Load                     0.066     0.151      0.049          -0.047
# Total Acceleration              0.039    -0.030      0.023           0.006
# Engine RPM                      0.066     0.307     -0.012          -0.094
# Pitch                           0.102     0.033      0.008          -0.011
# Lateral Acceleration           -0.017     0.002     -0.001          -0.006
# Passenger Count                 1.000     0.343      0.076           0.140
# Car Load                        0.343     1.000     -0.149          -0.307
# AC Status                       0.076    -0.149      1.000           0.101
# Window Opening                  0.140    -0.307      0.101           1.000
# Radio Volume                   -0.376    -0.532      0.312           0.036
# Rain Intensity                  0.456    -0.149      0.250          -0.105
# Visibility                      0.012     0.326     -0.058           0.177
# Driver Wellbeing                0.157     0.478      0.074          -0.136
# Driver Rush                    -0.468    -0.011     -0.025          -0.473
# SHIFT                           0.198     0.658     -0.165          -0.151
#
#                       Radio Volume  Rain Intensity  Visibility  \
# Time                        -0.258          -0.023      -0.004
# Vehicle Speed               -0.323          -0.211       0.296
# Engine Load                  0.059          -0.001       0.068
# Total Acceleration           0.065           0.052      -0.016
# Engine RPM                  -0.040          -0.075       0.152
# Pitch                        0.067           0.061       0.018
# Lateral Acceleration         0.003          -0.001      -0.007
# Passenger Count             -0.376           0.456       0.012
# Car Load                    -0.532          -0.149       0.326
# AC Status                    0.312           0.250      -0.058
# Window Opening               0.036          -0.105       0.177
# Radio Volume                 1.000           0.094      -0.143
# Rain Intensity               0.094           1.000      -0.650
# Visibility                  -0.143          -0.650       1.000
# Driver Wellbeing            -0.210          -0.064       0.140
# Driver Rush                  0.119           0.022      -0.232
# SHIFT                       -0.393          -0.233       0.312
#
#                       Driver Wellbeing  Driver Rush  SHIFT
# Time                             0.114        0.187  0.153
# Vehicle Speed                    0.271       -0.002  0.859
# Engine Load                      0.061        0.001  0.057
# Total Acceleration              -0.021       -0.003 -0.225
# Engine RPM                       0.119        0.033  0.262
# Pitch                           -0.011       -0.018 -0.015
# Lateral Acceleration            -0.005        0.021  0.004
# Passenger Count                  0.157       -0.468  0.198
# Car Load                         0.478       -0.011  0.658
# AC Status                        0.074       -0.025 -0.165
# Window Opening                  -0.136       -0.473 -0.151
# Radio Volume                    -0.210        0.119 -0.393
# Rain Intensity                  -0.064        0.022 -0.233
# Visibility                       0.140       -0.232  0.312
# Driver Wellbeing                 1.000       -0.097  0.274
# Driver Rush                     -0.097        1.000 -0.040
# SHIFT                            0.274       -0.040  1.000

# %%
# Correlation Matrix
# ALL FEATURES seaborn graph
# No GridSearchCV take into consideration

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
heat = sns.heatmap(correlation_matrix, annot=True, cmap='RdYlBu', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# Correlation Matrix
# ALL FEATURES with threshold > 0.50
# No GridSearchCV take into consideration

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

threshold = 0.50
filtered_data = np.where(correlation_matrix > threshold, correlation_matrix, np.nan)

filtered_df = pd.DataFrame(filtered_data, index=correlation_matrix.index, columns=correlation_matrix.columns)

plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(filtered_df, cmap='RdBu', annot=True, fmt=".2f", linewidths=.5, annot_kws={"size": 10})
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %%
# Code to perform Grid Search Cross-Validation to find the best parameters
# 4 FEATURES
# 4 FEATURES

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# Get feature importance
feature_importance = clf.feature_importances_
feature_names = X.columns

feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})

print(feature_importance_df.sort_values(by='Importance', ascending=False))

most_important_features_df = feature_importance_df[feature_importance_df['Importance'] > 0.001]
most_important_features_df = most_important_features_df[most_important_features_df['Feature'] != 'Car Load']

X_five = df[most_important_features_df['Feature']]
y_five = df['SHIFT']

x_train_five, x_test_five, y_train_five, y_test_five = train_test_split(X_five, y_five, test_size=0.3, random_state=42)

# Define hyperparameters and values to search
# This aims to find the best set of hyperparameters for your machine learning model.
# Grid Search, which exhaustively evaluates all combinations of hyperparameters
param_grid = {
    'max_depth': [5, 7, 9],                  # Depth of the tree
    'min_samples_split': [3, 7, 10],         # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 4, 6]            # Minimum number of samples required to be at a leaf node
}

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the model on the training data
clf.fit(x_train_five, y_train_five)

# Predictions
predictions = clf.predict(x_test_five)

print(f"Accuracy: {accuracy_score(y_test_five, predictions)}")

print(f"Classification Report: {classification_report(y_test_five, predictions)}")

# Grid Search Cross-Validation to find the best parameters
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5)
grid_search.fit(x_train_five, y_train_five)

# Get the best parameters found by Grid Search
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Train the model with the best hyperparameters
best_clf = DecisionTreeClassifier(random_state=42, **best_params)
best_clf.fit(x_train_five, y_train_five)

# 5-fold cross-validation
cv_scores = cross_val_score(best_clf, X_five, y_five, cv=5)
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", cv_scores.mean())
# Out:
# Accuracy: 0.9999824453611867
# Classification Report:               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     60899
#            2       1.00      1.00      1.00    201252
#            3       1.00      1.00      1.00    244905
#            4       1.00      1.00      1.00    199911
#            5       1.00      1.00      1.00    261438
#
#     accuracy                           1.00    968405
#    macro avg       1.00      1.00      1.00    968405
# weighted avg       1.00      1.00      1.00    968405
#
# Best Hyperparameters: {'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 3}
# Cross-Validation Scores: [0.98586748 0.9992689  0.98994428 0.99945477 0.99035011]
# Mean CV Score: 0.9929771082228551

# %%
# Code to generate Confusion Matrix
# 4 MOST IMPORTANT FEATURES
# Vehicle Speed, Engine RPM, Total Acceleration, Pitch
# WITH GridSearchCV take into consideration
# BUT using max_depth = 5

import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt


# Train a Decision Tree Classifier with best params
best_params = grid_search.best_params_
clf = DecisionTreeClassifier(random_state=42, max_depth= 5, min_samples_leaf= 1, min_samples_split=3)
clf.fit(x_train_five, y_train_five)

# Predict clusters for the test data
predictions = clf.predict(x_test_five)

print(f"Accuracy: {accuracy_score(y_test_five, predictions)}")

print(f"Classification Report: {classification_report(y_test_five, predictions)}")

predicted_clusters = clf.predict(x_test_five)

conf_matrix = confusion_matrix(y_test_five, predicted_clusters)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['SHIFT'], yticklabels=['SHIFT'])
plt.xlabel('Predicted SHIFT')
plt.ylabel('True SHIFT')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.9515719146431504
# Classification Report:               precision    recall  f1-score   support
#
#            1       0.99      0.94      0.97     60899
#            2       0.92      0.97      0.94    201252
#            3       0.97      0.93      0.95    244905
#            4       0.94      0.94      0.94    199911
#            5       0.97      0.96      0.96    261438
#
#     accuracy                           0.95    968405
#    macro avg       0.96      0.95      0.95    968405
# weighted avg       0.95      0.95      0.95    968405

# %%
# Code to try to extract rules

from sklearn.tree import _tree

# Function to extract rules from decision tree
def extract_rules(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    def recurse(node):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print(f"If {name} <= {threshold}:")
            recurse(tree_.children_left[node])
            print(f"Else (If {name} > {threshold}): ")
            recurse(tree_.children_right[node])
        else:
            print(f"Predict Class {tree_.value[node]} \n")

    recurse(0)

extract_rules(best_clf, feature_names=list(X.columns))
# Out:
# If Time <= 54.95940017700195:
# If Time <= 30.90042018890381:
# If Time <= 14.725619792938232:
# If Engine Load <= 1198.5499877929688:
# If Time <= 9.391319751739502:
# Predict Class [[32436.     0.     0.     0.     0.]]
#
# Else (If Time > 9.391319751739502):
# Predict Class [[    0. 35285.     0.     0.     0.]]
#
# Else (If Engine Load > 1198.5499877929688):
# If Time <= 14.327459812164307:
# If Engine Load <= 1223.75:
# If Time <= 11.65176010131836:
# Predict Class [[2281.    0.    0.    0.    0.]]
#
# Else (If Time > 11.65176010131836):
# Predict Class [[ 0. 53.  0.  0.  0.]]
#
# Else (If Engine Load > 1223.75):
# If Time <= 14.258339881896973:
# If Time <= 14.233139991760254:
# Predict Class [[70119.     0.     0.     0.     0.]]
#
# Else (If Time > 14.233139991760254):
# If Engine Load <= 1583.7999877929688:
# Predict Class [[0. 1. 0. 0. 0.]]
#
# Else (If Engine Load > 1583.7999877929688):
# Predict Class [[197.   0.   0.   0.   0.]]
#
# Else (If Time > 14.258339881896973):
# If Engine Load <= 1584.2000122070312:
# Predict Class [[0. 6. 0. 0. 0.]]
#
# Else (If Engine Load > 1584.2000122070312):
# Predict Class [[512.   0.   0.   0.   0.]]
#
# Else (If Time > 14.327459812164307):
# If Engine Load <= 1588.3500366210938:
# Predict Class [[  0. 499.   0.   0.   0.]]
#
# Else (If Engine Load > 1588.3500366210938):
# Predict Class [[2685.    0.    0.    0.    0.]]
#
# Else (If Time > 14.725619792938232):
# If Engine Load <= 1642.5499877929688:
# If Time <= 20.976659774780273:
# If Engine Load <= 1144.1499633789062:
# If Time <= 15.094260215759277:
# If Engine Load <= 971.7450256347656:
# Predict Class [[ 0.  0. 57.  0.  0.]]
#
# Else (If Engine Load > 971.7450256347656):
# Predict Class [[  0. 238.   0.   0.   0.]]
#
# Else (If Time > 15.094260215759277):
# If Time <= 15.181739807128906:
# If Engine Load <= 987.4149780273438:
# Predict Class [[ 0.  0. 15.  0.  0.]]
#
# Else (If Engine Load > 987.4149780273438):
# Predict Class [[0. 8. 0. 0. 0.]]
#
# Else (If Time > 15.181739807128906):
# Predict Class [[   0.    0. 8945.    0.    0.]]
#
# Else (If Engine Load > 1144.1499633789062):
# If Engine Load <= 1155.4500122070312:
# If Time <= 17.93754005432129:
# Predict Class [[  0. 238.   0.   0.   0.]]
#
# Else (If Time > 17.93754005432129):
# Predict Class [[ 0.  0. 68.  0.  0.]]
#
# Else (If Engine Load > 1155.4500122070312):
# If Engine Load <= 1163.1499633789062:
# If Time <= 18.066420078277588:
# Predict Class [[  0. 349.   0.   0.   0.]]
#
# Else (If Time > 18.066420078277588):
# Predict Class [[ 0.  0. 13.  0.  0.]]
#
# Else (If Engine Load > 1163.1499633789062):
# If Engine Load <= 1165.0499877929688:
# Predict Class [[  0. 118.   1.   0.   0.]]
#
# Else (If Engine Load > 1165.0499877929688):
# Predict Class [[     0. 118801.      0.      0.      0.]]
#
# Else (If Time > 20.976659774780273):
# If Engine Load <= 1111.1499633789062:
# If Time <= 22.330979347229004:
# Predict Class [[  0.   0. 344.   0.   0.]]
#
# Else (If Time > 22.330979347229004):
# If Time <= 29.92572021484375:
# If Engine Load <= 858.4299926757812:
# Predict Class [[ 0.  0.  0.  0. 14.]]
#
# Else (If Engine Load > 858.4299926757812):
# Predict Class [[   0.    0.    0. 3736.    0.]]
#
# Else (If Time > 29.92572021484375):
# If Engine Load <= 1022.8600158691406:
# Predict Class [[ 0.  0.  0.  0. 80.]]
#
# Else (If Engine Load > 1022.8600158691406):
# Predict Class [[ 0.  0.  0. 41.  0.]]
#
# Else (If Engine Load > 1111.1499633789062):
# If Time <= 21.259079933166504:
# If Engine Load <= 1370.7000122070312:
# Predict Class [[   0.    0. 1693.    0.    0.]]
#
# Else (If Engine Load > 1370.7000122070312):
# Predict Class [[   0. 1472.    0.    0.    0.]]
#
# Else (If Time > 21.259079933166504):
# If Engine Load <= 1162.75:
# If Time <= 25.8647403717041:
# Predict Class [[   0.    0. 1916.    0.    0.]]
#
# Else (If Time > 25.8647403717041):
# Predict Class [[   0.    0.    0. 1655.    0.]]
#
# Else (If Engine Load > 1162.75):
# If Time <= 21.568140029907227:
# Predict Class [[  0. 153. 168.   0.   0.]]
#
# Else (If Time > 21.568140029907227):
# Predict Class [[0.00000e+00 6.70000e+01 1.13135e+05 3.72000e+02 0.00000e+00]]
#
# Else (If Engine Load > 1642.5499877929688):
# If Time <= 20.0132999420166:
# If Engine Load <= 1848.449951171875:
# Predict Class [[  0. 521.   0.   0.   0.]]
#
# Else (If Engine Load > 1848.449951171875):
# Predict Class [[25945.     0.     0.     0.     0.]]
#
# Else (If Time > 20.0132999420166):
# If Engine Load <= 2705.0499267578125:
# If Time <= 30.517739295959473:
# If Engine Load <= 1654.5499877929688:
# If Time <= 25.849260330200195:
# Predict Class [[   0. 3954.    0.    0.    0.]]
#
# Else (If Time > 25.849260330200195):
# Predict Class [[  0.   0. 395.   0.   0.]]
#
# Else (If Engine Load > 1654.5499877929688):
# If Time <= 30.350699424743652:
# Predict Class [[0.00000e+00 2.18094e+05 7.90000e+01 0.00000e+00 0.00000e+00]]
#
# Else (If Time > 30.350699424743652):
# Predict Class [[   0. 2129.   75.    0.    0.]]
#
# Else (If Time > 30.517739295959473):
# If Engine Load <= 2003.6000366210938:
# Predict Class [[   0.    0. 1822.    0.    0.]]
#
# Else (If Engine Load > 2003.6000366210938):
# Predict Class [[   0. 5092.    0.    0.    0.]]
#
# Else (If Engine Load > 2705.0499267578125):
# Predict Class [[7936.    0.    0.    0.    0.]]
#
# Else (If Time > 30.90042018890381):
# If Engine Load <= 1850.3500366210938:
# If Time <= 35.3377799987793:
# If Engine Load <= 1471.699951171875:
# If Engine Load <= 1101.9500122070312:
# Predict Class [[  0.   0.   0.   0. 255.]]
#
# Else (If Engine Load > 1101.9500122070312):
# Predict Class [[    0.     0.     0. 11909.     0.]]
#
# Else (If Engine Load > 1471.699951171875):
# Predict Class [[     0.      0. 103757.      0.      0.]]
#
# Else (If Time > 35.3377799987793):
# If Time <= 49.62419891357422:
# If Engine Load <= 1393.75:
# If Time <= 37.657798767089844:
# If Engine Load <= 1225.6500244140625:
# Predict Class [[  0.   0.   0.   0. 330.]]
#
# Else (If Engine Load > 1225.6500244140625):
# Predict Class [[   0.    0.    0. 7394.    0.]]
#
# Else (If Time > 37.657798767089844):
# If Total Acceleration <= 2.1287500858306885:
# If Time <= 38.102399826049805:
# Predict Class [[  0.   0.   0.  27. 147.]]
#
# Else (If Time > 38.102399826049805):
# Predict Class [[    0.     0.     0.     0. 10802.]]
#
# Else (If Total Acceleration > 2.1287500858306885):
# Predict Class [[ 0.  0.  0. 17.  0.]]
#
# Else (If Engine Load > 1393.75):
# If Engine Load <= 1501.1499633789062:
# If Time <= 42.969600677490234:
# Predict Class [[    0.     0.     0. 26884.     0.]]
#
# Else (If Time > 42.969600677490234):
# Predict Class [[   0.    0.    0.    0. 6078.]]
#
# Else (If Engine Load > 1501.1499633789062):
# If Time <= 37.39139938354492:
# Predict Class [[  0.   0. 571.   0.   0.]]
#
# Else (If Time > 37.39139938354492):
# If Engine Load <= 1503.6499633789062:
# Predict Class [[  0.   0.   0. 800.  62.]]
#
# Else (If Engine Load > 1503.6499633789062):
# Predict Class [[0.0000e+00 0.0000e+00 0.0000e+00 2.1227e+05 4.2000e+01]]
#
# Else (If Time > 49.62419891357422):
# If Engine Load <= 1755.0499877929688:
# Predict Class [[    0.     0.     0.     0. 19369.]]
#
# Else (If Engine Load > 1755.0499877929688):
# Predict Class [[  0.   0.   0. 733.   0.]]
#
# Else (If Engine Load > 1850.3500366210938):
# If Time <= 48.817800521850586:
# If Engine Load <= 2459.050048828125:
# If Time <= 33.168779373168945:
# Predict Class [[   0. 6567.    0.    0.    0.]]
#
# Else (If Time > 33.168779373168945):
# If Time <= 47.599199295043945:
# If Time <= 47.53260040283203:
# Predict Class [[     0.      0. 270328.      0.      0.]]
#
# Else (If Time > 47.53260040283203):
# If Engine Load <= 2145.3500366210938:
# Predict Class [[0. 0. 0. 2. 0.]]
#
# Else (If Engine Load > 2145.3500366210938):
# Predict Class [[ 0.  0. 10.  0.  0.]]
#
# Else (If Time > 47.599199295043945):
# If Engine Load <= 2162.3500366210938:
# Predict Class [[   0.    0.    0. 1466.    0.]]
#
# Else (If Engine Load > 2162.3500366210938):
# Predict Class [[ 0.  0. 63.  0.  0.]]
#
# Else (If Engine Load > 2459.050048828125):
# If Time <= 45.89099884033203:
# If Engine Load <= 3978.0001220703125:
# If Time <= 44.80379867553711:
# If Time <= 44.67060089111328:
# Predict Class [[    0. 69492.     0.     0.     0.]]
#
# Else (If Time > 44.67060089111328):
# Predict Class [[  0. 143.   4.   0.   0.]]
#
# Else (If Time > 44.80379867553711):
# If Engine Load <= 2993.60009765625:
# Predict Class [[  0.   0. 358.   0.   0.]]
#
# Else (If Engine Load > 2993.60009765625):
# Predict Class [[   0. 1038.    0.    0.    0.]]
#
# Else (If Engine Load > 3978.0001220703125):
# Predict Class [[411.   0.   0.   0.   0.]]
#
# Else (If Time > 45.89099884033203):
# If Engine Load <= 3078.7999267578125:
# Predict Class [[    0.     0. 20640.     0.     0.]]
#
# Else (If Engine Load > 3078.7999267578125):
# Predict Class [[   0. 2042.    0.    0.    0.]]
#
# Else (If Time > 48.817800521850586):
# If Engine Load <= 2329.6500244140625:
# Predict Class [[    0.     0.     0. 68905.     0.]]
#
# Else (If Engine Load > 2329.6500244140625):
# If Engine Load <= 3375.3499755859375:
# Predict Class [[    0.     0. 27600.     0.     0.]]
#
# Else (If Engine Load > 3375.3499755859375):
# Predict Class [[   0. 2271.    0.    0.    0.]]
#
# Else (If Time > 54.95940017700195):
# If Vehicle Speed <= 0.7824349999427795:
# If Time <= 61.94340133666992:
# If Engine Load <= 1961.25:
# Predict Class [[    0.     0.     0.     0. 48438.]]
#
# Else (If Engine Load > 1961.25):
# If Engine Load <= 2594.8499755859375:
# Predict Class [[    0.     0.     0. 40909.     0.]]
#
# Else (If Engine Load > 2594.8499755859375):
# Predict Class [[   0.    0. 3430.    0.    0.]]
#
# Else (If Time > 61.94340133666992):
# If Engine Load <= 2314.449951171875:
# If Total Acceleration <= 5.591799974441528:
# If Engine Load <= 2306.6500244140625:
# If Time <= 62.55900001525879:
# If Engine Load <= 2099.449951171875:
# Predict Class [[   0.    0.    0.    0. 8177.]]
#
# Else (If Engine Load > 2099.449951171875):
# Predict Class [[ 0.  0.  0. 56.  0.]]
#
# Else (If Time > 62.55900001525879):
# Predict Class [[     0.      0.      0.      0. 299827.]]
#
# Else (If Engine Load > 2306.6500244140625):
# If Time <= 68.7888011932373:
# Predict Class [[ 0.  0.  0. 57.  0.]]
#
# Else (If Time > 68.7888011932373):
# Predict Class [[   0.    0.    0.    0. 1876.]]
#
# Else (If Total Acceleration > 5.591799974441528):
# If Engine Load <= 2117.5499877929688:
# Predict Class [[ 0.  0.  0.  0. 51.]]
#
# Else (If Engine Load > 2117.5499877929688):
# Predict Class [[ 0.  0.  0. 25.  0.]]
#
# Else (If Engine Load > 2314.449951171875):
# If Time <= 76.80059814453125:
# If Engine Load <= 3069.800048828125:
# If Engine Load <= 2333.550048828125:
# If Time <= 69.22260093688965:
# Predict Class [[  0.   0.   0. 693.   0.]]
#
# Else (If Time > 69.22260093688965):
# Predict Class [[  0.   0.   0.   0. 472.]]
#
# Else (If Engine Load > 2333.550048828125):
# If Engine Load <= 2337.3499755859375:
# If Time <= 69.75900077819824:
# Predict Class [[  0.   0.   0. 195.   0.]]
#
# Else (If Time > 69.75900077819824):
# Predict Class [[ 0.  0.  0.  0. 46.]]
#
# Else (If Engine Load > 2337.3499755859375):
# If Time <= 76.71599960327148:
# Predict Class [[0.0000e+00 0.0000e+00 0.0000e+00 4.1613e+04 1.4000e+01]]
#
# Else (If Time > 76.71599960327148):
# Predict Class [[ 0.  0.  0. 83. 20.]]
#
# Else (If Engine Load > 3069.800048828125):
# Predict Class [[   0.    0. 1897.    0.    0.]]
#
# Else (If Time > 76.80059814453125):
# If Engine Load <= 3425.449951171875:
# If Time <= 89.9802017211914:
# If Engine Load <= 2791.5:
# Predict Class [[    0.     0.     0.     0. 49885.]]
#
# Else (If Engine Load > 2791.5):
# Predict Class [[   0.    0.    0. 9779.    0.]]
#
# Else (If Time > 89.9802017211914):
# If Engine Load <= 3363.050048828125:
# If Engine Load <= 3361.550048828125:
# Predict Class [[     0.      0.      0.      0. 141180.]]
#
# Else (If Engine Load > 3361.550048828125):
# Predict Class [[  0.   0.   0.   8. 135.]]
#
# Else (If Engine Load > 3363.050048828125):
# If Time <= 100.42200088500977:
# Predict Class [[  0.   0.   0. 554.   0.]]
#
# Else (If Time > 100.42200088500977):
# Predict Class [[   0.    0.    0.    0. 3943.]]
#
# Else (If Engine Load > 3425.449951171875):
# If Time <= 110.59379959106445:
# If Time <= 85.91759872436523:
# Predict Class [[  0.   0. 130.   0.   0.]]
#
# Else (If Time > 85.91759872436523):
# Predict Class [[   0.    0.    0. 3690.    0.]]
#
# Else (If Time > 110.59379959106445):
# Predict Class [[  0.   0.   0.   0. 350.]]
#
# Else (If Vehicle Speed > 0.7824349999427795):
# If Vehicle Speed <= 1.3357000350952148:
# If Engine Load <= 2185.449951171875:
# If Time <= 58.364999771118164:
# If Engine Load <= 1898.75:
# Predict Class [[  0.   0.   0.   0. 276.]]
#
# Else (If Engine Load > 1898.75):
# Predict Class [[   0.    0.    0. 1966.    0.]]
#
# Else (If Time > 58.364999771118164):
# If Time <= 58.4783992767334:
# If Total Acceleration <= 2.869749903678894:
# Predict Class [[0. 0. 0. 0. 9.]]
#
# Else (If Total Acceleration > 2.869749903678894):
# Predict Class [[0. 0. 0. 5. 0.]]
#
# Else (If Time > 58.4783992767334):
# Predict Class [[   0.    0.    0.    0. 5199.]]
#
# Else (If Engine Load > 2185.449951171875):
# If Time <= 87.96780014038086:
# If Engine Load <= 3323.1500244140625:
# If Time <= 58.019399642944336:
# If Engine Load <= 2506.4500732421875:
# Predict Class [[ 0.  0.  0. 84.  0.]]
#
# Else (If Engine Load > 2506.4500732421875):
# Predict Class [[  0.   0. 740.   0.   0.]]
#
# Else (If Time > 58.019399642944336):
# If Engine Load <= 2638.6500244140625:
# If Time <= 71.4906005859375:
# Predict Class [[   0.    0.    0. 9089.    0.]]
#
# Else (If Time > 71.4906005859375):
# Predict Class [[   0.    0.    0.    0. 3717.]]
#
# Else (If Engine Load > 2638.6500244140625):
# If Time <= 66.19859886169434:
# Predict Class [[  0.   0. 371.   0.   0.]]
#
# Else (If Time > 66.19859886169434):
# Predict Class [[    0.     0.     0. 14442.    84.]]
#
# Else (If Engine Load > 3323.1500244140625):
# If Time <= 62.1864013671875:
# Predict Class [[0. 8. 0. 0. 0.]]
#
# Else (If Time > 62.1864013671875):
# If Engine Load <= 4729.39990234375:
# If Time <= 87.8057975769043:
# Predict Class [[   0.    0. 1484.    0.    0.]]
#
# Else (If Time > 87.8057975769043):
# Predict Class [[0. 0. 0. 1. 0.]]
#
# Else (If Engine Load > 4729.39990234375):
# Predict Class [[0. 2. 0. 0. 0.]]
#
# Else (If Time > 87.96780014038086):
# If Engine Load <= 3295.3499755859375:
# If Engine Load <= 3284.949951171875:
# Predict Class [[   0.    0.    0.    0. 8027.]]
#
# Else (If Engine Load > 3284.949951171875):
# If Time <= 98.55899810791016:
# Predict Class [[ 0.  0.  0. 19.  0.]]
#
# Else (If Time > 98.55899810791016):
# Predict Class [[  0.   0.   0.   0. 153.]]
#
# Else (If Engine Load > 3295.3499755859375):
# If Time <= 109.71540069580078:
# If Engine Load <= 4519.550048828125:
# If Time <= 109.65959930419922:
# Predict Class [[   0.    0.    0. 5462.    0.]]
#
# Else (If Time > 109.65959930419922):
# Predict Class [[0. 0. 0. 5. 2.]]
#
# Else (If Engine Load > 4519.550048828125):
# Predict Class [[ 0.  0. 80.  0.  0.]]
#
# Else (If Time > 109.71540069580078):
# If Engine Load <= 3785.85009765625:
# Predict Class [[  0.   0.   0.   0. 606.]]
#
# Else (If Engine Load > 3785.85009765625):
# Predict Class [[  0.   0.   0. 248.   0.]]
#
# Else (If Vehicle Speed > 1.3357000350952148):
# If Vehicle Speed <= 2.000249981880188:
# If Engine Load <= 2854.949951171875:
# If Time <= 55.067399978637695:
# If Engine Load <= 2465.5499267578125:
# Predict Class [[0. 0. 0. 6. 0.]]
#
# Else (If Engine Load > 2465.5499267578125):
# Predict Class [[0. 0. 3. 0. 0.]]
#
# Else (If Time > 55.067399978637695):
# Predict Class [[  0.   0.   0. 677.   0.]]
#
# Else (If Engine Load > 2854.949951171875):
# If Time <= 77.95980072021484:
# If Engine Load <= 4219.5:
# If Engine Load <= 2922.5999755859375:
# If Time <= 65.84580039978027:
# Predict Class [[  0.   0. 247.   0.   0.]]
#
# Else (If Time > 65.84580039978027):
# Predict Class [[ 0.  0.  0. 53.  0.]]
#
# Else (If Engine Load > 2922.5999755859375):
# If Time <= 77.86800003051758:
# Predict Class [[   0.    0. 7360.    0.    0.]]
#
# Else (If Time > 77.86800003051758):
# Predict Class [[ 0.  0. 28.  2.  0.]]
#
# Else (If Engine Load > 4219.5):
# Predict Class [[  0. 280.   0.   0.   0.]]
#
# Else (If Time > 77.95980072021484):
# If Engine Load <= 3814.5999755859375:
# Predict Class [[  0.   0.   0. 716.   0.]]
#
# Else (If Engine Load > 3814.5999755859375):
# Predict Class [[   0.    0. 2274.    0.    0.]]
#
# Else (If Vehicle Speed > 2.000249981880188):
# If Engine Load <= 4185.10009765625:
# Predict Class [[  0.   0. 128.   0.   0.]]
#
# Else (If Engine Load > 4185.10009765625):
# Predict Class [[   0. 1624.    0.    0.    0.]]

# %% [markdown]
# Group rules by shift prediction

# %%
import numpy as np

# Initialize the dictionary
gears_pred = {
    1: [],
    2: [],
    3: [],
    4: [],
    5: []
}

def get_rules(tree, feature_names, class_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    paths = []
    path = []

    def recurse(node, path, paths):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            p1, p2 = list(path), list(path)
            p1 += [f"({name} <= {np.round(threshold, 3)})"]
            recurse(tree_.children_left[node], p1, paths)
            p2 += [f"({name} > {np.round(threshold, 3)})"]
            recurse(tree_.children_right[node], p2, paths)
        else:
            path += [(tree_.value[node], tree_.n_node_samples[node])]
            paths += [path]

    recurse(0, path, paths)

    # Sort by samples count
    samples_count = [p[-1][1] for p in paths]
    ii = list(np.argsort(samples_count))
    paths = [paths[i] for i in reversed(ii)]

    rules = []
    for path in paths:
        rule = "if "

        for p in path[:-1]:
            if rule != "if ":
                rule += " and "
            rule += str(p)
        rule += " then "

        if class_names is None:
            response = np.round(path[-1][0][0], 3)
            class_str = f"class: {response} ({int(response)} to 5)"
        else:
            classes = path[-1][0][0]
            class_idx = np.argmax(classes)
            response = class_names[class_idx]
            proba = np.round(100.0 * classes[class_idx] / np.sum(classes), 2)
            class_str = f"class: {response}" #(proba: {proba}%)"

        rule += f"{class_str} " #| based on {path[-1][1]:,} samples"
        gears_pred[int(response)].append(rule)
        rules.append(rule)

    return rules

# Define class names for your case
class_names = ['1', '2', '3', '4', '5']

rules = get_rules(clf, clf.feature_names_in_, class_names)
# for r in rules:
#     print(r)

# Print the rules associated with each class
for gear_num, rules in gears_pred.items():
    print(f"\nClass {gear_num}:")
    for rule in rules:
        print(f" {rule}")
# Out:
# Class 1:
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed <= 30.9) and (Vehicle Speed <= 14.726) and (Engine RPM > 1198.55) and (Vehicle Speed <= 14.327) then class: 1
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed <= 30.9) and (Vehicle Speed <= 14.726) and (Engine RPM <= 1198.55) and (Vehicle Speed <= 9.391) then class: 1
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed <= 30.9) and (Vehicle Speed > 14.726) and (Engine RPM > 1642.55) and (Vehicle Speed <= 20.013) then class: 1
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed <= 30.9) and (Vehicle Speed <= 14.726) and (Engine RPM > 1198.55) and (Vehicle Speed > 14.327) then class: 1
#
# Class 2:
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed <= 30.9) and (Vehicle Speed > 14.726) and (Engine RPM > 1642.55) and (Vehicle Speed > 20.013) then class: 2
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed <= 30.9) and (Vehicle Speed > 14.726) and (Engine RPM <= 1642.55) and (Vehicle Speed <= 20.977) then class: 2
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed > 30.9) and (Engine RPM > 1850.35) and (Vehicle Speed <= 48.818) and (Engine RPM > 2459.05) then class: 2
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed <= 30.9) and (Vehicle Speed <= 14.726) and (Engine RPM <= 1198.55) and (Vehicle Speed > 9.391) then class: 2
#  if (Vehicle Speed > 54.959) and (Total Acceleration > 0.782) and (Total Acceleration > 1.336) and (Total Acceleration > 2.0) and (Engine RPM > 4185.1) then class: 2
#
# Class 3:
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed > 30.9) and (Engine RPM > 1850.35) and (Vehicle Speed <= 48.818) and (Engine RPM <= 2459.05) then class: 3
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed <= 30.9) and (Vehicle Speed > 14.726) and (Engine RPM <= 1642.55) and (Vehicle Speed > 20.977) then class: 3
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed > 30.9) and (Engine RPM <= 1850.35) and (Vehicle Speed <= 35.338) and (Engine RPM > 1471.7) then class: 3
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed > 30.9) and (Engine RPM > 1850.35) and (Vehicle Speed > 48.818) and (Engine RPM > 2329.65) then class: 3
#  if (Vehicle Speed > 54.959) and (Total Acceleration > 0.782) and (Total Acceleration > 1.336) and (Total Acceleration <= 2.0) and (Engine RPM > 2854.95) then class: 3
#  if (Vehicle Speed > 54.959) and (Total Acceleration <= 0.782) and (Vehicle Speed <= 61.943) and (Engine RPM > 1961.25) and (Engine RPM > 2594.85) then class: 3
#  if (Vehicle Speed > 54.959) and (Total Acceleration > 0.782) and (Total Acceleration > 1.336) and (Total Acceleration > 2.0) and (Engine RPM <= 4185.1) then class: 3
#
# Class 4:
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed > 30.9) and (Engine RPM <= 1850.35) and (Vehicle Speed > 35.338) and (Vehicle Speed <= 49.624) then class: 4
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed > 30.9) and (Engine RPM > 1850.35) and (Vehicle Speed > 48.818) and (Engine RPM <= 2329.65) then class: 4
#  if (Vehicle Speed > 54.959) and (Total Acceleration <= 0.782) and (Vehicle Speed > 61.943) and (Engine RPM > 2314.45) and (Vehicle Speed <= 76.801) then class: 4
#  if (Vehicle Speed > 54.959) and (Total Acceleration <= 0.782) and (Vehicle Speed <= 61.943) and (Engine RPM > 1961.25) and (Engine RPM <= 2594.85) then class: 4
#  if (Vehicle Speed > 54.959) and (Total Acceleration > 0.782) and (Total Acceleration <= 1.336) and (Engine RPM > 2185.45) and (Vehicle Speed <= 87.968) then class: 4
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed > 30.9) and (Engine RPM <= 1850.35) and (Vehicle Speed <= 35.338) and (Engine RPM <= 1471.7) then class: 4
#  if (Vehicle Speed > 54.959) and (Total Acceleration > 0.782) and (Total Acceleration <= 1.336) and (Engine RPM <= 2185.45) and (Vehicle Speed <= 58.365) then class: 4
#  if (Vehicle Speed > 54.959) and (Total Acceleration > 0.782) and (Total Acceleration > 1.336) and (Total Acceleration <= 2.0) and (Engine RPM <= 2854.95) then class: 4
#
# Class 5:
#  if (Vehicle Speed > 54.959) and (Total Acceleration <= 0.782) and (Vehicle Speed > 61.943) and (Engine RPM <= 2314.45) and (Pitch <= 5.592) then class: 5
#  if (Vehicle Speed > 54.959) and (Total Acceleration <= 0.782) and (Vehicle Speed > 61.943) and (Engine RPM > 2314.45) and (Vehicle Speed > 76.801) then class: 5
#  if (Vehicle Speed > 54.959) and (Total Acceleration <= 0.782) and (Vehicle Speed <= 61.943) and (Engine RPM <= 1961.25) then class: 5
#  if (Vehicle Speed <= 54.959) and (Vehicle Speed > 30.9) and (Engine RPM <= 1850.35) and (Vehicle Speed > 35.338) and (Vehicle Speed > 49.624) then class: 5
#  if (Vehicle Speed > 54.959) and (Total Acceleration > 0.782) and (Total Acceleration <= 1.336) and (Engine RPM > 2185.45) and (Vehicle Speed > 87.968) then class: 5
#  if (Vehicle Speed > 54.959) and (Total Acceleration > 0.782) and (Total Acceleration <= 1.336) and (Engine RPM <= 2185.45) and (Vehicle Speed > 58.365) then class: 5
#  if (Vehicle Speed > 54.959) and (Total Acceleration <= 0.782) and (Vehicle Speed > 61.943) and (Engine RPM <= 2314.45) and (Pitch > 5.592) then class: 5
